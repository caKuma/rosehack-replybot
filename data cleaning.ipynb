# %%
import pandas as pd
csv = pd.read_csv("/content/emails_text.csv", encoding="latin1")
csv = csv.replace('/n','', regex=True)
csv = csv.replace('\n','', regex=True)
csv
# Out:
#       Unnamed: 0                                               text
# 0              1  URGENT BUSINESS ASSISTANCE AND PARTNERSHIP.DEA...
# 1              2  Dear Friend,I am Mr. Ben Suleman a custom offi...
# 2              3  FROM HIS ROYAL MAJESTY (HRM) CROWN RULER OF EL...
# 3              4  FROM HIS ROYAL MAJESTY (HRM) CROWN RULER OF EL...
# 4              5  Dear sir,  It is with a heart full of hope tha...
# ...          ...                                                ...
# 5182        5183  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; <BR>&nbsp...
# 5183        5184  rahim Danko.</DIV><br /><hr />Invite your mail...
# 5184        5185  Beloved in the Lord Jesus Christ, PLEASE ENDEA...
# 5185        5186  husband's family. Hoping to hear from you.Repl...
# 5186        5187  Mr.Huang Chi-LinBank SinoPacExecutive Vice Pre...
#
# [5187 rows x 2 columns]

# %%
csv.to_csv("/content/emails_text_nlpy.csv")
